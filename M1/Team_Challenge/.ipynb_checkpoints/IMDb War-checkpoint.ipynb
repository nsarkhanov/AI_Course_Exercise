# %% [markdown]
# # Importing Packages

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns

# %% [markdown]
# # Getting Data

# %%
time = pd.read_csv("time.csv")

# %%
x = pd.read_csv("Films_details.csv")

# %%
x
# Out:
#     Unnamed: 0                   Title    Year Duration  \
# 0            0         The Mountain II  (2016)  135 min
# 1            1     Saving Private Ryan  (1998)  169 min
# 2            2       Life Is Beautiful  (1997)  116 min
# 3            3             The Pianist  (2002)  150 min
# 4            4  Grave of the Fireflies  (1988)   89 min
# ..         ...                     ...     ...      ...
# 95          95   From Here to Eternity  (1953)  118 min
# 96          96                Lifeboat  (1944)   97 min
# 97          97             Son of Saul  (2015)  107 min
# 98          98           Lone Survivor  (2013)  121 min
# 99          99         The Hurt Locker  (2008)  131 min
#
#                        Genre  Rating  \
# 0         Action, Drama, War     8.8
# 1                 Drama, War     8.6
# 2     Comedy, Drama, Romance     8.6
# 3    Biography, Drama, Music     8.5
# 4      Animation, Drama, War     8.5
# ..                       ...     ...
# 95       Drama, Romance, War     7.6
# 96                Drama, War     7.6
# 97                Drama, War     7.5
# 98  Action, Biography, Drama     7.5
# 99      Drama, Thriller, War     7.5
#
#                                           Description          Director  \
# 0   In a desolate war zone where screams of the in...      Alper Caglar
# 1   Following the Normandy Landings, a group of U....  Steven Spielberg
# 2   When an open-minded Jewish librarian and his s...   Roberto Benigni
# 3   A Polish Jewish musician struggles to survive ...    Roman Polanski
# 4   A young boy and his little sister struggle to ...     Isao Takahata
# ..                                                ...               ...
# 95  In Hawaii in 1941, a private is cruelly punish...    Fred Zinnemann
# 96  Several survivors of a torpedoed merchant ship...  Alfred Hitchcock
# 97  A Jewish-Hungarian concentration camp prisoner...      László Nemes
# 98  Marcus Luttrell and his team set out on a miss...        Peter Berg
# 99  During the Iraq War, a Sergeant recently assig...   Kathryn Bigelow
#
#                                                 Stars
# 0   Ertugrul,,Ufuk,Bayraktar,,Ahu,Türkpençe,,Murat...
# 1       Hanks,,Matt,Damon,,Tom,Sizemore,,Edward,Burns
# 2   Benigni,,Nicoletta,Braschi,,Giorgio,Cantarini,...
# 3   Brody,,Thomas,Kretschmann,,Frank,Finlay,,Emili...
# 4   Tatsumi,,Ayano,Shiraishi,,Akemi,Yamaguchi,,Yos...
# ..                                                ...
# 95  Lancaster,,Montgomery,Clift,,Deborah,Kerr,,Don...
# 96  Bankhead,,John,Hodiak,,Walter,Slezak,,William,...
# 97   Röhrig,,Levente,Molnár,,Urs,Rechn,,Todd,Charmont
# 98  Wahlberg,,Taylor,Kitsch,,Emile,Hirsch,,Ben,Foster
# 99  Renner,,Anthony,Mackie,,Brian,Geraghty,,Guy,Pe...
#
# [100 rows x 9 columns]

# %%
War = pd.concat([x,time],axis=1)

# %%
War.keys()
# Out:
# Index(['Unnamed: 0', 'Title', 'Year', 'Duration', 'Genre', 'Rating',
#        'Description', 'Director', 'Stars', 'Unnamed: 0', 'Unnamed: 0.1',
#        'Filming Dates'],
#       dtype='object')

# %%
War = War.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1)

# %%
War.keys()
# Out:
# Index(['Title', 'Year', 'Duration', 'Genre', 'Rating', 'Description',
#        'Director', 'Stars', 'Filming Dates'],
#       dtype='object')

# %%
War
# Out:
#                      Title    Year Duration                     Genre  Rating  \
# 0          The Mountain II  (2016)  135 min        Action, Drama, War     8.8
# 1      Saving Private Ryan  (1998)  169 min                Drama, War     8.6
# 2        Life Is Beautiful  (1997)  116 min    Comedy, Drama, Romance     8.6
# 3              The Pianist  (2002)  150 min   Biography, Drama, Music     8.5
# 4   Grave of the Fireflies  (1988)   89 min     Animation, Drama, War     8.5
# ..                     ...     ...      ...                       ...     ...
# 95   From Here to Eternity  (1953)  118 min       Drama, Romance, War     7.6
# 96                Lifeboat  (1944)   97 min                Drama, War     7.6
# 97             Son of Saul  (2015)  107 min                Drama, War     7.5
# 98           Lone Survivor  (2013)  121 min  Action, Biography, Drama     7.5
# 99         The Hurt Locker  (2008)  131 min      Drama, Thriller, War     7.5
#
#                                           Description          Director  \
# 0   In a desolate war zone where screams of the in...      Alper Caglar
# 1   Following the Normandy Landings, a group of U....  Steven Spielberg
# 2   When an open-minded Jewish librarian and his s...   Roberto Benigni
# 3   A Polish Jewish musician struggles to survive ...    Roman Polanski
# 4   A young boy and his little sister struggle to ...     Isao Takahata
# ..                                                ...               ...
# 95  In Hawaii in 1941, a private is cruelly punish...    Fred Zinnemann
# 96  Several survivors of a torpedoed merchant ship...  Alfred Hitchcock
# 97  A Jewish-Hungarian concentration camp prisoner...      László Nemes
# 98  Marcus Luttrell and his team set out on a miss...        Peter Berg
# 99  During the Iraq War, a Sergeant recently assig...   Kathryn Bigelow
#
#                                                 Stars  \
# 0   Ertugrul,,Ufuk,Bayraktar,,Ahu,Türkpençe,,Murat...
# 1       Hanks,,Matt,Damon,,Tom,Sizemore,,Edward,Burns
# 2   Benigni,,Nicoletta,Braschi,,Giorgio,Cantarini,...
# 3   Brody,,Thomas,Kretschmann,,Frank,Finlay,,Emili...
# 4   Tatsumi,,Ayano,Shiraishi,,Akemi,Yamaguchi,,Yos...
# ..                                                ...
# 95  Lancaster,,Montgomery,Clift,,Deborah,Kerr,,Don...
# 96  Bankhead,,John,Hodiak,,Walter,Slezak,,William,...
# 97   Röhrig,,Levente,Molnár,,Urs,Rechn,,Todd,Charmont
# 98  Wahlberg,,Taylor,Kitsch,,Emile,Hirsch,,Ben,Foster
# 99  Renner,,Anthony,Mackie,,Brian,Geraghty,,Guy,Pe...
#
#                        Filming Dates
# 0                 No Dates available
# 1   27 June 1997 - 13 September 1997
# 2       June 1997 - 5 September 1997
# 3       19 February 2001 - July 2001
# 4                 No Dates available
# ..                               ...
# 95         7 March 1953 - 5 May 1953
# 96  3 August 1943 - 17 November 1943
# 97                No Dates available
# 98                    2 October 2012
# 99     23 July 2007 - September 2007
#
# [100 rows x 9 columns]

# %%
War
# Out:
#                      Title    Year Duration                     Genre  Rating  \
# 0          The Mountain II  (2016)  135 min        Action, Drama, War     8.8
# 1      Saving Private Ryan  (1998)  169 min                Drama, War     8.6
# 2        Life Is Beautiful  (1997)  116 min    Comedy, Drama, Romance     8.6
# 3              The Pianist  (2002)  150 min   Biography, Drama, Music     8.5
# 4   Grave of the Fireflies  (1988)   89 min     Animation, Drama, War     8.5
# ..                     ...     ...      ...                       ...     ...
# 95   From Here to Eternity  (1953)  118 min       Drama, Romance, War     7.6
# 96                Lifeboat  (1944)   97 min                Drama, War     7.6
# 97             Son of Saul  (2015)  107 min                Drama, War     7.5
# 98           Lone Survivor  (2013)  121 min  Action, Biography, Drama     7.5
# 99         The Hurt Locker  (2008)  131 min      Drama, Thriller, War     7.5
#
#                                           Description          Director  \
# 0   In a desolate war zone where screams of the in...      Alper Caglar
# 1   Following the Normandy Landings, a group of U....  Steven Spielberg
# 2   When an open-minded Jewish librarian and his s...   Roberto Benigni
# 3   A Polish Jewish musician struggles to survive ...    Roman Polanski
# 4   A young boy and his little sister struggle to ...     Isao Takahata
# ..                                                ...               ...
# 95  In Hawaii in 1941, a private is cruelly punish...    Fred Zinnemann
# 96  Several survivors of a torpedoed merchant ship...  Alfred Hitchcock
# 97  A Jewish-Hungarian concentration camp prisoner...      László Nemes
# 98  Marcus Luttrell and his team set out on a miss...        Peter Berg
# 99  During the Iraq War, a Sergeant recently assig...   Kathryn Bigelow
#
#                                                 Stars  \
# 0   Ertugrul,,Ufuk,Bayraktar,,Ahu,Türkpençe,,Murat...
# 1       Hanks,,Matt,Damon,,Tom,Sizemore,,Edward,Burns
# 2   Benigni,,Nicoletta,Braschi,,Giorgio,Cantarini,...
# 3   Brody,,Thomas,Kretschmann,,Frank,Finlay,,Emili...
# 4   Tatsumi,,Ayano,Shiraishi,,Akemi,Yamaguchi,,Yos...
# ..                                                ...
# 95  Lancaster,,Montgomery,Clift,,Deborah,Kerr,,Don...
# 96  Bankhead,,John,Hodiak,,Walter,Slezak,,William,...
# 97   Röhrig,,Levente,Molnár,,Urs,Rechn,,Todd,Charmont
# 98  Wahlberg,,Taylor,Kitsch,,Emile,Hirsch,,Ben,Foster
# 99  Renner,,Anthony,Mackie,,Brian,Geraghty,,Guy,Pe...
#
#                        Filming Dates
# 0                 No Dates available
# 1   27 June 1997 - 13 September 1997
# 2       June 1997 - 5 September 1997
# 3       19 February 2001 - July 2001
# 4                 No Dates available
# ..                               ...
# 95         7 March 1953 - 5 May 1953
# 96  3 August 1943 - 17 November 1943
# 97                No Dates available
# 98                    2 October 2012
# 99     23 July 2007 - September 2007
#
# [100 rows x 9 columns]

# %% [markdown]
# # Normalizing Data

# %%
normalized_Ratings_series=(War["Rating"]-War["Rating"].min())/(War["Rating"].max()-War["Rating"].min())
normalized_ratings=pd.DataFrame(normalized_Ratings_series)
normalized_ratings
# Out:
#       Rating
# 0   1.000000
# 1   0.846154
# 2   0.846154
# 3   0.769231
# 4   0.769231
# ..       ...
# 95  0.076923
# 96  0.076923
# 97  0.000000
# 98  0.000000
# 99  0.000000
#
# [100 rows x 1 columns]

# %% [markdown]
# # Graphs

# %%
Y = War.sort_values(['Year'], ascending=True)

# %%
# Movies' Rating by Year.


plt.figure(figsize=(20,7))
plt.xticks(rotation=45, ha='right')
plt.scatter(Y['Year'],Y['Rating'])
plt.title("Movies Through The Years")
plt.show()

# %%
# Number Movies' in top 100 by Director.


plt.figure(figsize=(20,10))
plt.xticks(rotation=45, ha='right')
plt.scatter(War['Director'],War['Rating'])

plt.show()

# %%
 War.sort_values(['Duration'], ascending=True)
# Out:
#                     Title        Year                 Duration  \
# 57           Land of Mine      (2015)                  100 min
# 66   To Have and Have Not      (1944)                  100 min
# 5              Casablanca      (1942)                  102 min
# 44  Au Revoir les Enfants      (1987)                  104 min
# 78      The African Queen      (1951)                  105 min
# ..                    ...         ...                      ...
# 96               Lifeboat      (1944)                   97 min
# 53          No Man's Land  (I) (2001)                   98 min
# 27     To Be or Not to Be      (1942)                   99 min
# 83     The Counterfeiters      (2007)                   99 min
# 42    Nefes - Der Atemzug      (2009)  Action, Drama, Thriller
#
#                            Genre  Rating  \
# 57           Drama, History, War     7.8
# 66  Adventure, Comedy, Film-Noir     7.8
# 5            Drama, Romance, War     8.5
# 44                    Drama, War     8.0
# 78     Adventure, Drama, Romance     7.7
# ..                           ...     ...
# 96                    Drama, War     7.6
# 53            Comedy, Drama, War     7.9
# 27                   Comedy, War     8.2
# 83         Crime, Drama, History     7.6
# 42                           NaN     8.0
#
#                                           Description           Director  \
# 57  In post-World War II Denmark, a group of young...   Martin Zandvliet
# 66  During World War II, American expatriate Harry...       Howard Hawks
# 5   A cynical expatriate American cafe owner strug...     Michael Curtiz
# 44  A French boarding school run by priests seems ...        Louis Malle
# 78  In WWI Africa, a gin-swilling riverboat captai...        John Huston
# ..                                                ...                ...
# 96  Several survivors of a torpedoed merchant ship...   Alfred Hitchcock
# 53  Bosnia and Herzegovina during 1993 at the time...      Danis Tanovic
# 27  During the Nazi occupation of Poland, an actin...     Ernst Lubitsch
# 83  The story of the Operation Bernhard, the large...  Stefan Ruzowitzky
# 42  Story of 40-man Turkish task force who must de...     Levent Semerci
#
#                                                 Stars  \
# 57  Møller,,Louis,Hofmann,,Joel,Basman,,Mikkel,Boe...
# 66  Bogart,,Lauren,Bacall,,Walter,Brennan,,Dolores...
# 5   Bogart,,Ingrid,Bergman,,Paul,Henreid,,Claude,R...
# 44  Manesse,,Raphael,Fejtö,,Francine,Racette,,Stan...
# 78  Bogart,,Katharine,Hepburn,,Robert,Morley,,Pete...
# ..                                                ...
# 96  Bankhead,,John,Hodiak,,Walter,Slezak,,William,...
# 53  Djuric,,Rene,Bitorajac,,Filip,Sovagovic,,Georg...
# 27  Lombard,,Jack,Benny,,Robert,Stack,,Felix,Bressart
# 83  Markovics,,August,Diehl,,Devid,Striesow,,Marti...
# 42  |,Stars:Mete,Horozoglu,,Ilker,Kizmaz,,Baris,Ba...
#
#                          Filming Dates
# 57             July 2014 - August 2014
# 66      29 February 1944 - 10 May 1944
# 5          25 May 1942 - 3 August 1942
# 44                     2 February 1987
# 78              May 1951 - August 1951
# ..                                 ...
# 96    3 August 1943 - 17 November 1943
# 53                  No Dates available
# 27  6 November 1941 - 24 December 1941
# 83          21 March 2006 - 4 May 2006
# 42                  No Dates available
#
# [100 rows x 9 columns]

# %%
ax=plt.figure(figsize=(20,10))
ax= plt.xticks(rotation=45, ha='right')
ax= plt.scatter(War['Duration'],War['Rating'])
ax.setxticks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-b39687ae07c4> in <module>
#       2 ax= plt.xticks(rotation=45, ha='right')
#       3 ax= plt.scatter(War['Duration'],War['Rating'])
# ----> 4 ax.setxticks
#       5 plt.show()
#
# AttributeError: 'PathCollection' object has no attribute 'setxticks'

# %%
War.describe()
# Out:
#            Rating
# count  100.000000
# mean     7.960000
# std      0.302181
# min      7.500000
# 25%      7.700000
# 50%      8.000000
# 75%      8.200000
# max      8.800000

# %%
War['Duration'].value_counts()
# Out:
# 116 min    4
# 131 min    4
# 121 min    4
# 138 min    3
# 120 min    2
#           ..
# 123 min    1
# 183 min    1
# 89 min     1
# 94 min     1
# 228 min    1
# Name: Duration, Length: 71, dtype: int64

# %%
Top10 = War.sort_values(['Rating'], ascending=False).head(10)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45, ha='right')
plt.scatter(Top10['Director'],Top10['Rating'])

plt.show()

# %%
plt.figure(figsize=(30,20))
t = War.groupby(['Director']).count()
t =
# Out:
#   File "<ipython-input-55-b367e24b28e3>", line 3
#     t =
#         ^
# SyntaxError: invalid syntax

# %%
T= t.sort_values(['Rating'], ascending=False).head(10)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45, ha='right')
plt.bar(T.index,T["Rating"])
plt.title("Number of Movies by Directors in Top 100")
# Out:
# Text(0.5, 1.0, 'Number of Movies by Directors in Top 100')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=86193761-2877-467f-bcb9-1f0b66feed89' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
